# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!unzip /content/drive/MyDrive/FashionMnist/sample_data/train_LbELtWX.zip
# !unzip /content/drive/MyDrive/FashionApparel/zipFiles/train_LbELtWX.zip -d /content/drive/MyDrive/FashionApparel/trainFiles
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/378.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/45712.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/57389.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/5260.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/58492.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/58143.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/616.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/25467.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/37219.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/55151.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/train/57860.png
# ...

# %%
train = pd.read_csv('/content/drive/MyDrive/FashionApparel/trainFiles/train.csv')

# %%
train.shape
# Out:
# (60000, 2)

# %%
train.head()
# Out:
#    id  label
# 0   1      9
# 1   2      0
# 2   3      0
# 3   4      3
# 4   5      0

# %%
load_img('/content/drive/MyDrive/FashionApparel/trainFiles/train/51111.png')
# Out:
# <PIL.Image.Image image mode=RGB size=28x28 at 0x7F77B13D6710>

# %%
# We have grayscale images, so while loading the images we will keep grayscale=True, if you have RGB images, you should set grayscale as False
train_image = []
for i in tqdm(range(train.shape[0])):
    img = image.load_img('/content/drive/MyDrive/FashionApparel/trainFiles/train/'+train['id'][i].astype('str')+'.png', target_size=(28,28,1), grayscale=True)
    img = image.img_to_array(img)
    img = img/255
    train_image.append(img)
X = np.array(train_image)
# Out:
#   0%|          | 0/60000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 100%|██████████| 60000/60000 [01:44<00:00, 574.64it/s]

# %%
y=train['label'].values
y = to_categorical(y)

# %%
train['label']
# Out:
# 0        9
# 1        0
# 2        0
# 3        3
# 4        0
#         ..
# 59995    5
# 59996    1
# 59997    3
# 59998    0
# 59999    5
# Name: label, Length: 60000, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=(28,28,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 143s 94ms/step - loss: 0.6612 - accuracy: 0.7673 - val_loss: 0.3100 - val_accuracy: 0.8876
# Epoch 2/10
# 1500/1500 [==============================] - 141s 94ms/step - loss: 0.3453 - accuracy: 0.8773 - val_loss: 0.2660 - val_accuracy: 0.9061
# Epoch 3/10
# 1500/1500 [==============================] - 139s 93ms/step - loss: 0.2858 - accuracy: 0.8974 - val_loss: 0.2508 - val_accuracy: 0.9071
# Epoch 4/10
# 1500/1500 [==============================] - 140s 94ms/step - loss: 0.2510 - accuracy: 0.9088 - val_loss: 0.2340 - val_accuracy: 0.9133
# Epoch 5/10
# 1500/1500 [==============================] - 140s 94ms/step - loss: 0.2207 - accuracy: 0.9193 - val_loss: 0.2405 - val_accuracy: 0.9103
# Epoch 6/10
# 1500/1500 [==============================] - 139s 93ms/step - loss: 0.2039 - accuracy: 0.9241 - val_loss: 0.2183 - val_accuracy: 0.9201
# Epoch 7/10
# ...

# %%
# !unzip '/content/drive/MyDrive/FashionApparel/zipFiles/test_ScVgIM0.zip' -d '/content/drive/MyDrive/FashionApparel/trainFiles'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/68337.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/62169.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/66934.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/66646.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/63831.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/60971.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/68881.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/60259.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/68746.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/67545.png
#  extracting: /content/drive/MyDrive/FashionApparel/trainFiles/test/60231.png
# ...

# %%
test = pd.read_csv('/content/drive/MyDrive/FashionApparel/trainFiles/test.csv')

# %%
test_image = []
for i in tqdm(range(test.shape[0])):
    img = image.load_img('/content/drive/MyDrive/FashionApparel/trainFiles/test/'+test['id'][i].astype('str')+'.png', target_size=(28,28,1), grayscale=True)
    img = image.img_to_array(img)
    img = img/255
    test_image.append(img)
test = np.array(test_image)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 100%|██████████| 10000/10000 [00:18<00:00, 527.40it/s]

# %%
# making predictions
prediction = model.predict_classes(test)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
# creating submission file
sample = pd.read_csv('/content/drive/MyDrive/FashionApparel/sample_submission_I5njJSF.csv')
sample['label'] = prediction
sample.to_csv('/content/drive/MyDrive/FashionApparel/trainFiles/sample_cnn.csv', header=True, index=False)
